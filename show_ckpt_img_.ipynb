# %%
import os
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from IPython.display import display

def show_PIL_image(image):
    plt.imshow(image)
    plt.axis('off')
    plt.xticks([])
    plt.yticks([])
    plt.show()
    
def image_grid(imgs, rows, cols):
    assert len(imgs) == rows*cols
    
    w, h = imgs[0].size
    grid = Image.new('RGB', size=(cols*w, rows*h))
    grid_w, grid_h = grid.size
    
    for i, img in enumerate(imgs):
        grid.paste(img, box=(i%cols*w, i//cols*h))
    return grid

# %% [markdown]
# # Test for "DEMO_NAME CKPT CAPTION"

# %%
# assert 1==2

root = '/oss/comicai/chenyu.liu/fastcomposer_release_danbooru/fastcomposer-main/outputs/'

DEMO_NAME_GENDERS = [
    "role1 girl", \
    "role2 girl", \
    "role3 girl", \
    "role4 girl", \
    "role5 girl", \
    "role6 boy", \
    "role7 boy", \
    "role8 boy", \
    "role9 boy", \
    "role10 boy", \
]
# DEMO_NAME_GENDERS = [
#     "Nahida girl", \
#     "6002903 girl", \
#     "Elsa girl", \
# ]
# DEMO_NAME_GENDERS = [
#     "Nahida_Elsa girl", \
# ]
# DEMO_NAME_GENDERS = [
#     "daji girl", \
# ]

CKPTS = [
    "220000", \
]
# CKPTS = [
#     "105000", \
#     "110000", \
#     "115000", \
# ]
# CKPTS = [
#     "65000", \
#     "70000", \
#     "75000", \
#     "80000", \
#     "85000", \
#     "90000", \
#     "95000", \
#     "100000", \
# ]
# CKPTS = [
#     "5000", \
#     "10000", \
#     "15000", \
#     "20000", \
#     "25000", \
#     "30000", \
#     "35000", \
# ]
# CKPTS = [
#     "30000", \
#     "35000", \
#     "40000", \
#     "45000", \
#     "50000", \
#     "55000", \
#     "60000", \
#     "65000", \
#     "70000", \
# ]
# CKPTS = [
#     "120000", \
#     "130000", \
#     "140000", \
#     "150000", \
#     "160000", \
#     "170000", \
#     "180000", \
#     "190000", \
#     "200000", \
#     "210000", \
# ]
CAPTIONS = [
    'a GENDER <|image|>, solo, sitting in the classroom', \
    'a GENDER <|image|>, solo, standing in the library', \
    'a GENDER <|image|>, solo, lying on the bed', \
    'a GENDER <|image|>, solo, running in the gym', \
    'a GENDER <|image|>, solo, holding flower in a forest with trees', \
    'a GENDER <|image|>, solo, victory pose, on the stage', \
]
# CAPTIONS = [
#     "a GENDER <|image|> is reading book", \
# ]
# CAPTIONS = [
#     "a GENDER <|image|> and a GENDER <|image|> are reading book together", \
# ]


num_rows = 4

for DEMO_NAME_GENDER in DEMO_NAME_GENDERS:
    DEMO_NAME, GENDER = DEMO_NAME_GENDER.split(' ')
    if CKPTS == []:
        CKPTS = os.listdir(os.path.join(root, DEMO_NAME))
    for CKPT in CKPTS:
        if CAPTIONS == []:
            CAPTIONS = os.listdir(os.path.join(root, DEMO_NAME, CKPT))
        for CAPTION in CAPTIONS:
            CAPTION = CAPTION.replace('GENDER', GENDER)
            
            path = os.path.join(root, DEMO_NAME, CKPT, CAPTION)
            print('path:', path)
            dir_or_files = os.listdir(path)
            dir_or_files = [dir_or_file for dir_or_file in dir_or_files if dir_or_file not in ['.ipynb_checkpoints']]
            
            pil_images = []
            for dir_file in dir_or_files:
                dir_file_path = os.path.join(path, dir_file)
                pil_images.append(Image.open(dir_file_path))
            
            print("DEMO_NAME:", DEMO_NAME, "GENDER:", GENDER, "CKPT:", CKPT, "CAPTION:", CAPTION)
            grid = image_grid(pil_images, num_rows, len(pil_images)//num_rows)
            display(grid)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 assert 1==2
#       3 root = '/nas40/chenyu.liu/fastcomposer_release_danbooru/fastcomposer-main/outputs/'
#       5 # DEMO_NAME_GENDERS = [
#       6 #     "role1 girl", \
#       7 #     "role2 girl", \
#    (...)
#      23 #     "Nahida_Elsa girl", \
#      24 # ]
#
# AssertionError:

# %% [markdown]
# # Test for "DEMO_NAME CKPT CAPTION POSE"

# %%
assert 1==2

root = '/oss/comicai/chenyu.liu/fastcomposer_release_danbooru/fastcomposer-main/outputs/'

# DEMO_NAME_GENDERS = [
#     "role1 girl", \
#     "role2 girl", \
#     "role3 girl", \
#     "role4 girl", \
#     "role5 girl", \
#     "role6 boy", \
#     "role7 boy", \
#     "role8 boy", \
#     "role9 boy", \
#     "role10 boy", \
# ]
# DEMO_NAME_GENDERS = [
#     "Nahida girl", \
#     "6002903 girl", \
#     "Elsa girl", \
# ]
# DEMO_NAME_GENDERS = [
#     "Nahida_Elsa girl", \
# ]
DEMO_NAME_GENDERS = [
    "role1 girl", \
]

CKPTS = [
    # "100000", \
    # "105000", \
    # "110000", \
    "115000", \
]
# CKPTS = [
#     "65000", \
#     "70000", \
#     "75000", \
#     "80000", \
#     "85000", \
#     "90000", \
#     "95000", \
#     "100000", \
# ]
# CKPTS = [
#     "5000", \
#     "10000", \
#     "15000", \
#     "20000", \
#     "25000", \
#     "30000", \
#     "35000", \
# ]
# CKPTS = [
#     "30000", \
#     "35000", \
#     "40000", \
#     "45000", \
#     "50000", \
#     "55000", \
#     "60000", \
#     "65000", \
#     "70000", \
# ]


# CAPTIONS = [
#     'a GENDER <|image|>, solo, sitting in the classroom', \
#     'a GENDER <|image|>, solo, standing in the library', \
#     'a GENDER <|image|>, solo, lying on the bed', \
#     'a GENDER <|image|>, solo, running in the gym', \
#     'a GENDER <|image|>, solo, holding flower in a forest with trees', \
#     'a GENDER <|image|>, solo, victory pose, on the stage', \
# ]
# CAPTIONS = [
#     "a GENDER <|image|> is reading book", \
# ]
# CAPTIONS = [
#     "a GENDER <|image|> and a GENDER <|image|> are reading book together", \
# ]
CAPTIONS = [
    "a GENDER <|image|>, solo, on the playground", \
]


# POSES = [
#     "001_stand/000000006_pose.jpg", \
#     "002_hold/000010006_pose.jpg", \
#     "003_sit/000020732_pose.jpg", \
#     "005_walk/000030054_pose.jpg", \
#     "007_play/000040005_pose.jpg", \
#     "008_look/000050028_pose.jpg", \
#     "010_ride/000070151_pose.jpg", \
#     "014_lay/000100001_pose.jpg", \
#     "016_do/000110006_pose.jpg", \
#     "020_run/000140007_pose.jpg", \
# ]
POSES = [
    "020_run/000140007_pose.jpg", \
]


num_rows = 1

for DEMO_NAME_GENDER in DEMO_NAME_GENDERS:
    DEMO_NAME, GENDER = DEMO_NAME_GENDER.split(' ')
    if CKPTS == []:
        # CKPTS = os.listdir(os.path.join(root, DEMO_NAME))
        root_demo_name = os.path.join(root, DEMO_NAME)
        CKPTS = [file for file in os.listdir(root_demo_name) if os.path.isfile(os.path.join(root_demo_name, file))]
    for CKPT in CKPTS:
        if CAPTIONS == []:
            # CAPTIONS = os.listdir(os.path.join(root, DEMO_NAME, CKPT))
            root_ckpt = os.path.join(root, DEMO_NAME, CKPT)
            CAPTIONS = [file for file in os.listdir(root_ckpt) if os.path.isfile(os.path.join(root_ckpt, file))]
        for CAPTION in CAPTIONS:
            CAPTION = CAPTION.replace('GENDER', GENDER)
            if POSES == []:
                root_caption = os.path.join(root, DEMO_NAME, CKPT, CAPTION)
                POSES = [file for file in os.listdir(root_caption) if os.path.isfile(os.path.join(root_caption, file))]
            for POSE in POSES:
                POSE = POSE.replace('/', ' ')
                
                path = os.path.join(root, DEMO_NAME, CKPT, CAPTION, POSE)
                print('path:', path)
                dir_or_files = os.listdir(path)
                dir_or_files = [dir_or_file for dir_or_file in dir_or_files if dir_or_file not in ['.ipynb_checkpoints']]
                
                pil_images = []
                for dir_file in dir_or_files:
                    dir_file_path = os.path.join(path, dir_file)
                    pil_images.append(Image.open(dir_file_path))
                
                print("DEMO_NAME:", DEMO_NAME, "GENDER:", GENDER, "CKPT:", CKPT, "CAPTION:", CAPTION, "POSE:", POSE)
                grid = image_grid(pil_images, num_rows, len(pil_images)//num_rows)
                display(grid)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 assert 1==2
#       3 root = '/nas40/chenyu.liu/fastcomposer_release_danbooru/fastcomposer-main/outputs/'
#       5 # DEMO_NAME_GENDERS = [
#       6 #     "role1 girl", \
#       7 #     "role2 girl", \
#    (...)
#      23 #     "Nahida_Elsa girl", \
#      24 # ]
#
# AssertionError:

# %% [markdown]
# # Individual Display

# %%
# assert 1==2

root_path = "/nas40/chenyu.liu/fastcomposer_release_danbooru/fastcomposer-main/data/train_fastcomposer_data_336k_pre_release_danbooru_/00000"
captions={}
dir_or_files = os.listdir(root_path) # 只有文件或文件夹的名称，没有前面的目录名称
dir_or_files = [x for x in dir_or_files if x not in [".ipynb_checkpoints", ".DS_Store"] and '.jpg' in x] # 删除所有特定元素
dir_or_files = sorted(dir_or_files)
print('len(dir_or_files):', len(dir_or_files))

pil_images = []
num_rows = 5

# dir_or_files = [
#     "1019085.jpg", \
#     "1019091.jpg", \
#     "1019110.jpg", \
#     "1019133.jpg", \
#     "1019153.jpg", \
#     "1019185.jpg", \
#     "1019214.jpg", \
#     "1019225.jpg", \
#     "1019227.jpg", \
#     "1019230.jpg", \
# ]

for dir_file in dir_or_files[:5]:
    dir_file_path = os.path.join(root_path, dir_file)
    pil_images.append(Image.open(dir_file_path))

grid = image_grid(pil_images, num_rows, len(pil_images)//num_rows)
display(grid)
